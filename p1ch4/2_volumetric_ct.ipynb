# %%
import numpy as np
import torch
torch.set_printoptions(edgeitems=2, threshold=50)

# %%
import imageio

dir_path = "../data/p1ch4/volumetric-dicom/2-LUNG 3.0  B70f-04083"
vol_arr = imageio.volread(dir_path, 'DICOM')
vol_arr.shape
# Out:
# Reading DICOM (examining files): 1/99 files (1.0%3/99 files (3.0%5/99 files (5.1%10/99 files (10.1%19/99 files (19.2%32/99 files (32.3%43/99 files (43.4%55/99 files (55.6%69/99 files (69.7%94/99 files (94.9%99/99 files (100.0%)
#   Found 1 correct series.
# Reading DICOM (loading data): 14/99  (14.131/99  (31.343/99  (43.454/99  (54.566/99  (66.780/99  (80.899/99  (100.0%)
# (99, 512, 512)

# %%
vol = torch.from_numpy(vol_arr).float()
vol = torch.unsqueeze(vol, 0)

vol.shape
# Out:
# torch.Size([1, 99, 512, 512])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
print(vol_arr[50].shape)
plt.imshow(vol_arr[50])
# Out:
# (512, 512)
